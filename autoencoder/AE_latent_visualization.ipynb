# %%
import pandas as pd
import numpy as np
import time

from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler, StandardScaler, RobustScaler

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh import palettes
from bokeh.models import Legend

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c53c56b0-4dd1-41a3-a2b6-37cfc6977efe">Loading BokehJS ...</span>
#     </div>

# %%
def load_latent(name=""):
    train_latent = np.load("../results/AE/train_latent_{0}.npy".format(name))
    val_latent = np.load("../results/AE/val_latent_{0}.npy".format(name))
    train_df = pd.read_csv("../data/train_val_test_split/seed0/train_fold0.csv", header=None, index_col=0)
    val_df = pd.read_csv("../data/train_val_test_split/seed0/val_fold0.csv", header=None, index_col=0)
    train_df["latent0"] = train_latent[:, 0]
    train_df["latent1"] = train_latent[:, 1]
    val_df["latent0"] = val_latent[:, 0]
    val_df["latent1"] = val_latent[:, 1]
    both_df = pd.concat([train_df, val_df]) 
    return train_df, val_df, both_df

# %%
train_df, val_df, both_df = load_latent(name="simple2")
p = figure(plot_width=800, plot_height=700)
p.circle(train_df["latent0"], train_df["latent1"], 
         size=3, color="green", alpha=0.6, legend="train")
p.circle(val_df["latent0"], val_df["latent1"], 
         size=3, color="red", alpha=0.6, legend="val")
p.legend.click_policy="hide"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6a433621-fa1c-432f-aef0-f48d72d0a4ed"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6a433621-fa1c-432f-aef0-f48d72d0a4ed");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6a433621-fa1c-432f-aef0-f48d72d0a4ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6a433621-fa1c-432f-aef0-f48d72d0a4ed' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca971ff0-9019-4c6b-9c47-a7e0ef4220c5":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"df9d3d0f-a460-48f0-9ebb-0d18eecd52cb","type":"PanTool"},{"id":"b42c1886-1f0e-4384-958f-815137dff434","type":"WheelZoomTool"},{"id":"296687d6-e881-40f7-8e37-b4b01deac22c","type":"BoxZoomTool"},{"id":"92d11ab5-53d6-4f0e-bb18-ac947c8ec0ac","type":"SaveTool"},{"id":"b41f604a-a824-4f48-ab09-9ee253f4c444","type":"ResetTool"},{"id":"4be3caa5-c33e-4e49-a162-ab408d13f28d","type":"HelpTool"}]},"id":"9ba24d02-933b-4930-ac78-9a824858c563","type":"Toolbar"},{"attributes":{"label":{"value":"train"},"renderers":[{"id":"a8dc12d6-a7d3-4986-8fb2-3ea5510ce321","type":"GlyphRenderer"}]},"id":"ce4e8f98-0ca9-409c-8dc8-95e155cafd72","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[2147]},"y":{"__ndarray__":"...","dtype":"float32","shape":[2147]}}},"id":"9239a445-faa2-40ff-814f-07ae208658ff","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"bc90f357-0905-4592-ad19-08c76a487131","type":"DataRange1d"},{"attributes":{},"id":"7c8648dc-d33b-4741-ad08-691063ace966","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"1822c49c-b828-4a37-8167-363e2c56a338","type":"ColumnDataSource"}},"id":"ec68251a-da14-496c-99b9-7e644ec8cb9f","type":"CDSView"},{"attributes":{},"id":"b1e1ff6f-3b26-4ae4-a26b-4f6009ef4826","type":"BasicTicker"},{"attributes":{},"id":"f5623c52-695a-4d6d-8143-dc2d57d2053f","type":"LinearScale"},{"attributes":{"click_policy":"hide","items":[{"id":"ce4e8f98-0ca9-409c-8dc8-95e155cafd72","type":"LegendItem"},{"id":"fb8caf7a-5c99-43f4-8e91-51cb4bcbeaa7","type":"LegendItem"}],"plot":{"id":"48783bfa-fc93-42e8-be0a-d724747c0605","subtype":"Figure","type":"Plot"}},"id":"06221955-89ed-456f-b401-de468061a646","type":"Legend"},{"attributes":{"callback":null},"id":"117c2b85-38b7-461d-bde9-d8a6b7827334","type":"DataRange1d"},{"attributes":{"source":{"id":"9239a445-faa2-40ff-814f-07ae208658ff","type":"ColumnDataSource"}},"id":"6cb2ce75-e968-4fc4-a457-5234aeee3601","type":"CDSView"},{"attributes":{"formatter":{"id":"95bd2424-9c82-4e41-b32b-65be59fe5813","type":"BasicTickFormatter"},"plot":{"id":"48783bfa-fc93-42e8-be0a-d724747c0605","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1e1ff6f-3b26-4ae4-a26b-4f6009ef4826","type":"BasicTicker"}},"id":"16b03fbe-12af-43de-9f38-b7a535b5eea9","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"e94e1fc5-35bf-45e7-88e3-5713de2b362c","type":"Title"},{"attributes":{},"id":"95bd2424-9c82-4e41-b32b-65be59fe5813","type":"BasicTickFormatter"},{"attributes":{},"id":"4348b136-be0c-4f73-a744-77e04d2c6c08","type":"LinearScale"},{"attributes":{"plot":{"id":"48783bfa-fc93-42e8-be0a-d724747c0605","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1e1ff6f-3b26-4ae4-a26b-4f6009ef4826","type":"BasicTicker"}},"id":"03993fe7-7b10-4172-b59d-3aecec937639","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"red"},"line_alpha":{"value":0.6},"line_color":{"value":"red"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"41e093c4-2288-4aac-ae05-4ac282575278","type":"Circle"},{"attributes":{"data_source":{"id":"9239a445-faa2-40ff-814f-07ae208658ff","type":"ColumnDataSource"},"glyph":{"id":"41e093c4-2288-4aac-ae05-4ac282575278","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8a0c2d6f-4601-46ec-9b6b-abc8108383ba","type":"Circle"},"selection_glyph":null,"view":{"id":"6cb2ce75-e968-4fc4-a457-5234aeee3601","type":"CDSView"}},"id":"6f4df355-a95c-4c67-9b96-5f3d0f10f025","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"48783bfa-fc93-42e8-be0a-d724747c0605","subtype":"Figure","type":"Plot"},"ticker":{"id":"6754b25b-c733-4849-be48-197d5275c0e1","type":"BasicTicker"}},"id":"833d917d-4eb3-4859-9a44-47516d61afe4","type":"Gr ...

# %%
label_df = pd.read_csv("../data/labels.csv", index_col="sample_id")
joined_df = label_df.join(both_df)

# %%
this_df = joined_df[["label_tissue", "latent0", "latent1"]].dropna()
colored_tissues = this_df["label_tissue"].value_counts().index

p = figure(plot_width=1000, plot_height=800)
with open("../colors.txt", "r") as f:
    colors = f.read().split(",")
for i, datatype in enumerate(colored_tissues):
    subset_df = this_df[this_df["label_tissue"] == datatype]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, color=colors[i], legend=datatype)
    
p.legend.click_policy="hide"
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5295332-8681-4f42-b7b9-ebef395ac126"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f5295332-8681-4f42-b7b9-ebef395ac126");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5295332-8681-4f42-b7b9-ebef395ac126");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5295332-8681-4f42-b7b9-ebef395ac126' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fe4c9562-47f9-4e9a-bf4f-9bc7502bbbd8":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#c49c94"},"line_color":{"value":"#c49c94"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"1385724f-ff43-412d-9671-cdc0b73c0209","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"98be0681-d8b1-4be5-b220-9a9c4bdbdd4c","type":"Circle"},{"attributes":{"data_source":{"id":"1b4e1cdc-64fe-4047-8159-31535a188827","type":"ColumnDataSource"},"glyph":{"id":"df5dff8a-040c-4857-9604-3d20f862ff1d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"98be0681-d8b1-4be5-b220-9a9c4bdbdd4c","type":"Circle"},"selection_glyph":null,"view":{"id":"75f3fe02-6739-4de6-8446-2f40a053e7bb","type":"CDSView"}},"id":"570edbc8-0e6b-40be-95db-81fa14be8687","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d442f667-0179-482b-b929-dc4a4a752a5e","type":"Circle"},{"attributes":{"data_source":{"id":"6cb3a3c1-61d4-4300-9c86-ffcabfa7017d","type":"ColumnDataSource"},"glyph":{"id":"1385724f-ff43-412d-9671-cdc0b73c0209","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d442f667-0179-482b-b929-dc4a4a752a5e","type":"Circle"},"selection_glyph":null,"view":{"id":"4ecb1bb7-0235-473a-b6b6-5878eaafe7ca","type":"CDSView"}},"id":"a3f93b89-8206-45ff-8fd4-9d58aaf1086a","type":"GlyphRenderer"},{"attributes":{"source":{"id":"1b4e1cdc-64fe-4047-8159-31535a188827","type":"ColumnDataSource"}},"id":"75f3fe02-6739-4de6-8446-2f40a053e7bb","type":"CDSView"},{"attributes":{"label":{"value":"UCS"},"renderers":[{"id":"570edbc8-0e6b-40be-95db-81fa14be8687","type":"GlyphRenderer"}]},"id":"800b630b-77c1-47e3-8085-1a4f1c3c4095","type":"LegendItem"},{"attributes":{"source":{"id":"6cb3a3c1-61d4-4300-9c86-ffcabfa7017d","type":"ColumnDataSource"}},"id":"4ecb1bb7-0235-473a-b6b6-5878eaafe7ca","type":"CDSView"},{"attributes":{"label":{"value":"DLBC"},"renderers":[{"id":"26f89ef8-6afb-4b01-94e7-5104b88d71f4","type":"GlyphRenderer"}]},"id":"a85e618c-9599-4918-9c70-a29db88d6c6e","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[159]},"y":{"__ndarray__":"...","dtype":"float32","shape":[159]}}},"id":"2c308dce-3c62-4046-b0e2-92f199d2a754","type":"ColumnDataSource"},{"attributes":{"source":{"id":"fc57a7ca-7c6a-4060-a64e-49624e88a1cc","type":"ColumnDataSource"}},"id":"bb0e552f-410d-4fa6-9ab2-7c68d2e7e81f","type":"CDSView"},{"attributes":{"label":{"value":"READ"},"renderers":[{"id":"a3f93b89-8206-45ff-8fd4-9d58aaf1086a","type":"GlyphRenderer"}]},"id":"4162164e-bac9-43b1-b103-b74449a6d5b4","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#bcbd22"},"line_color":{"value":"#bcbd22"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"f5b2226b-7ab9-41ed-ac4b-f076290375af","type":"Circle"},{"attributes":{"data_source":{"id":"9b1f5b4b-0fd2-44ff-9c9e-43970adf5294","type":"ColumnDataSource"},"glyph":{"id":"4e4671c0-059c-4f14-9a13-3bd45d4ec488","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8bb3cde4-c813-48bd-9718-dd37736a7001","type":"Circle"},"selection_glyph":null,"view":{"id":"a5751c6f-f39b-4e76-a9df-fb7e834e7b51","type":"CDSView"}},"id":"122aa730-a5da-41c9-a06b-69a4fc36cf5b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"adb944b6-4e28-4160-b136-849804efda0d","type":"Circle"},{"attributes" ...

# %%
this_df = joined_df[["label_gender", "latent0", "latent1"]].dropna()
colored_genders = this_df["label_gender"].value_counts().index

p = figure(plot_width=800, plot_height=800)
colors = palettes.Category10[10]
for i, datatype in enumerate(colored_genders):
    subset_df = this_df[this_df["label_gender"] == datatype]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, 
             alpha=0.7, color=colors[i], legend=datatype)
    
p.legend.click_policy="hide"
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3428882a-c694-4c4d-b145-5622f2e373a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3428882a-c694-4c4d-b145-5622f2e373a9");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3428882a-c694-4c4d-b145-5622f2e373a9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3428882a-c694-4c4d-b145-5622f2e373a9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fc55bfde-ba88-471a-975f-cc56ea38008e":{"roots":{"references":[{"attributes":{"label":{"value":"FEMALE"},"renderers":[{"id":"96e0e169-e197-4cfe-97be-76251d0152ff","type":"GlyphRenderer"}]},"id":"66d4a8ad-59f4-4649-8be0-c27459a7376e","type":"LegendItem"},{"attributes":{},"id":"757b453c-2e9d-4559-a883-df87c13157cd","type":"BasicTicker"},{"attributes":{},"id":"d974ed6c-87f1-434e-9194-a519ff2a2161","type":"BasicTickFormatter"},{"attributes":{},"id":"e27da1e4-7e12-47cb-9ed4-1a1e9122af97","type":"LinearScale"},{"attributes":{},"id":"7542943d-f226-4f0f-9072-cb47b81efbce","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#ff7f0e"},"line_alpha":{"value":0.7},"line_color":{"value":"#ff7f0e"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"8def0672-05ca-4f22-b4a9-ae29fe8813de","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[5301]},"y":{"__ndarray__":"...","dtype":"float32","shape":[5301]}}},"id":"3237f17a-dfda-437a-96ff-9513c8daf4cf","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[5029]},"y":{"__ndarray__":"...","dtype":"float32","shape":[5029]}}},"id":"5a3ea767-d7c1-4ef6-a5bf-b0aa13f88925","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"d974ed6c-87f1-434e-9194-a519ff2a2161","type":"BasicTickFormatter"},"plot":{"id":"dbf225d4-e4cf-45c8-8c69-e28a3f7d23fc","subtype":"Figure","type":"Plot"},"ticker":{"id":"9e3f20d0-855d-4e80-8317-a7e89b9b8621","type":"BasicTicker"}},"id":"80470a9a-5dfb-4377-bc37-da23ae5835c7","type":"LinearAxis"},{"attributes":{"callback":null},"id":"8781d294-4ac1-4375-ae8f-0780a34ca577","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.7},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"86a575bd-7362-405e-bfd4-0bec8aaddf67","type":"Circle"},{"attributes":{},"id":"c07f5217-e2f5-4271-8993-5e5f1bdd7dd4","type":"ResetTool"},{"attributes":{"label":{"value":"MALE"},"renderers":[{"id":"06467386-3621-48b4-8580-ff2b4b8ec5bc","type":"GlyphRenderer"}]},"id":"22c1f764-eb8b-4511-90ae-4b684796adc4","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5574b2bc-25be-4073-b0f4-9862af5653d8","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"38bfe79c-1a84-497c-940e-0d64cc81bf42","type":"BasicTickFormatter"},"plot":{"id":"dbf225d4-e4cf-45c8-8c69-e28a3f7d23fc","subtype":"Figure","type":"Plot"},"ticker":{"id":"757b453c-2e9d-4559-a883-df87c13157cd","type":"BasicTicker"}},"id":"05ce8b06-e73f-4e21-bde3-342b7ffc4795","type":"LinearAxis"},{"attributes":{"source":{"id":"3237f17a-dfda-437a-96ff-9513c8daf4cf","type":"ColumnDataSource"}},"id":"ac4aba2f-6540-47aa-9267-ef7b55fa52e3","type":"CDSView"},{"attributes":{},"id":"c3c77fa3-cca7-4fd4-8a20-e102dccb21ae","type":"SaveTool"},{"attributes":{},"id":"38bfe79c-1a84-497c-940e-0d64cc81bf42","type":"BasicTickFormatter"},{"attributes":{},"id":"bdb40546-2c8b-41fd-9baa-b44be04921b1","type":"LinearScale"},{"attributes":{},"id":"9e3f20d0-855d-4e80-8317-a7e89b9b8621","type":"BasicTicker"},{"attributes":{},"id":"b57c830a-c78c-4f5e-8c80-9ef6ba950d7d","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"57ac6fed-a94f-426d-9301-a561a2e86a74","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b ...

# %%
this_df = joined_df[["label_tumor", "latent0", "latent1"]].dropna()
colored_tumors = this_df["label_tumor"].value_counts().index

p = figure(plot_width=800, plot_height=800)
colors = palettes.Category10[10]
for i, datatype in enumerate(colored_tumors):
    subset_df = this_df[this_df["label_tumor"] == datatype]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, 
             alpha=0.7, color=colors[i], legend=datatype)
    
p.legend.click_policy="hide"
p.legend.location = "top_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="166740a9-ff22-4d3e-bf17-ae47aa9396b9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("166740a9-ff22-4d3e-bf17-ae47aa9396b9");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("166740a9-ff22-4d3e-bf17-ae47aa9396b9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '166740a9-ff22-4d3e-bf17-ae47aa9396b9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25f56565-ffd1-48d1-81ba-f1e532533e54":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5586dbf-fe6f-4315-8fa5-c081dd2875f7","type":"Circle"},{"attributes":{"formatter":{"id":"28302ab9-f4d8-4eeb-acdc-3d4ab16b5e03","type":"BasicTickFormatter"},"plot":{"id":"f57633f1-27a1-4c01-b1e6-eba1fe38e625","subtype":"Figure","type":"Plot"},"ticker":{"id":"15283038-0a4c-48c0-85b6-08c7af01e71d","type":"BasicTicker"}},"id":"edd6fc23-ad09-4b7e-a37e-4c3e534e33d1","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"526c76e5-7d4c-40a2-a525-586614bbcecf","type":"BoxAnnotation"},{"attributes":{"click_policy":"hide","items":[{"id":"c57dae67-5606-4b20-bc53-b18624639eb6","type":"LegendItem"},{"id":"dd8c3506-d945-4245-aee3-6cbf279b29f1","type":"LegendItem"},{"id":"c7a89fed-2d5c-4a53-a6c8-7d6a95367ed0","type":"LegendItem"},{"id":"237f450c-a5f5-4906-9640-6daa7434b2ac","type":"LegendItem"},{"id":"66432b42-6ded-4645-be1f-225021f02592","type":"LegendItem"}],"plot":{"id":"f57633f1-27a1-4c01-b1e6-eba1fe38e625","subtype":"Figure","type":"Plot"}},"id":"779b4984-3705-48e9-be17-3d6eb4cbcaa0","type":"Legend"},{"attributes":{"plot":null,"text":""},"id":"4d653b17-7263-4ba5-8df6-cd3623a77ed0","type":"Title"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#9467bd"},"line_alpha":{"value":0.7},"line_color":{"value":"#9467bd"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"3eaf328b-904e-4741-9d26-fee7855d17f0","type":"Circle"},{"attributes":{"data_source":{"id":"22cf041c-2794-4c75-9c66-3503563ffd43","type":"ColumnDataSource"},"glyph":{"id":"7e1c8b05-d6dd-4032-8d63-5de0a54a917c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bb6f1a06-9974-406d-a7c8-b157d3a28c5f","type":"Circle"},"selection_glyph":null,"view":{"id":"8e81cdb3-0e1f-4b82-9d29-c507d6644b98","type":"CDSView"}},"id":"086f8d1c-5354-42ef-974e-53ce0abae2e7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d82bd838-35d9-491b-b45b-6fc5d857b6e1","type":"ColumnDataSource"},"glyph":{"id":"5adfc92c-d00c-432a-a4c6-adf4f95c897b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d563e32e-fe9c-41c9-91a2-088b063b28b9","type":"Circle"},"selection_glyph":null,"view":{"id":"831fb791-c2f1-44f5-b227-487014df7db7","type":"CDSView"}},"id":"81c37b03-fe1d-4ec7-8365-395e463b3ee6","type":"GlyphRenderer"},{"attributes":{},"id":"5a07e4e6-4ae8-4b1d-a576-3b217c72fc76","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"f57633f1-27a1-4c01-b1e6-eba1fe38e625","subtype":"Figure","type":"Plot"},"ticker":{"id":"15283038-0a4c-48c0-85b6-08c7af01e71d","type":"BasicTicker"}},"id":"790e13a2-b4ff-4826-99a1-b4c86b94e35c","type":"Grid"},{"attributes":{},"id":"28302ab9-f4d8-4eeb-acdc-3d4ab16b5e03","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"36978282-27da-4826-9c4f-721994823983","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#2ca02c"},"line_alpha":{"value":0.7},"line_color":{"value":"#2ca02c"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7e1c8b05-d6dd-4032-8d63-5de0a54a917c","type":"Circle"},{"attributes":{},"id":"15283038-0a4c-48c0-85b6-08c7af01e71d","type":"BasicTicker"},{"attributes":{"callback":null},"id":"b7506be9-0761-436d-a7a6-06902d42cfa1","type ...

# %%
this_df = joined_df[["label_age", "latent0", "latent1"]].dropna()
this_df["age_bin"] = this_df["label_age"].apply(lambda x:int(x/10)-1)

p = figure(plot_width=800, plot_height=800)
colors = palettes.Category10[10]
rainbow = palettes.RdBu11[:4] + palettes.RdBu11[-5:]
for i in sorted(list(set(this_df["age_bin"]))):
    subset_df = this_df[this_df["age_bin"] == i]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, 
             alpha=0.7, color=rainbow[i], legend="{0}0s".format(i+1))
    
p.legend.click_policy="hide"
p.legend.location = "top_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e5386988-7a54-4dac-8b32-4f32518057a2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("e5386988-7a54-4dac-8b32-4f32518057a2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e5386988-7a54-4dac-8b32-4f32518057a2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e5386988-7a54-4dac-8b32-4f32518057a2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4d213c5c-5aae-4b05-a046-6fb40c311645":{"roots":{"references":[{"attributes":{"label":{"value":"30s"},"renderers":[{"id":"99f2c873-122e-4e90-bcc7-9cd6ca87483d","type":"GlyphRenderer"}]},"id":"079c30c7-acfa-4134-b299-6c817fe714bf","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d0969f5b-d4d0-4f12-b371-2e8bfafc1db2","type":"Circle"},{"attributes":{},"id":"c1d209e4-2930-477e-a6d0-3ed612019a32","type":"LinearScale"},{"attributes":{"data_source":{"id":"f5b73344-d2bd-4eea-baba-139ef2f769b8","type":"ColumnDataSource"},"glyph":{"id":"bea18f55-8e61-424b-acae-85c0d8e7b81b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"14d7c422-87c8-4daf-87ce-ef5e2a5920f0","type":"Circle"},"selection_glyph":null,"view":{"id":"f9bde16c-8392-4481-9329-6e580cfdc28c","type":"CDSView"}},"id":"10807163-feb1-4548-92a7-7bcebd34eb94","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c081e528-3d9d-4057-b50e-d3b86ce43631","type":"Circle"},{"attributes":{"label":{"value":"90s"},"renderers":[{"id":"3ceb45e4-dfb2-4565-abfd-e69cbffb9022","type":"GlyphRenderer"}]},"id":"c73b7c45-c990-42af-beb5-1e2a277b03b7","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#92c5de"},"line_alpha":{"value":0.7},"line_color":{"value":"#92c5de"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b443efba-0737-40d6-a9c6-9b54fd03041f","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#d6604d"},"line_alpha":{"value":0.7},"line_color":{"value":"#d6604d"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"bea18f55-8e61-424b-acae-85c0d8e7b81b","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"ed191ca5-feb1-450d-85a3-4d6ad07e7296","type":"Circle"},{"attributes":{},"id":"b1556256-89e0-48e9-b641-ea875ef7be44","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"60s"},"renderers":[{"id":"30715f8a-bc68-4d32-aa39-811a95b7fc9d","type":"GlyphRenderer"}]},"id":"e9f1ab90-94ca-4c3e-9131-d014468e9a4c","type":"LegendItem"},{"attributes":{"label":{"value":"50s"},"renderers":[{"id":"490c2018-0089-4e25-949e-67c7dd07e11a","type":"GlyphRenderer"}]},"id":"b4a190cc-7ac9-4ebd-9730-8062c9672d48","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#4393c3"},"line_alpha":{"value":0.7},"line_color":{"value":"#4393c3"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7e744ce0-b26e-4c04-a27e-c580cb17385d","type":"Circle"},{"attributes":{"data_source":{"id":"58693f77-8b48-4211-93d1-ab43b132e1be","type":"ColumnDataSource"},"glyph":{"id":"dd953d36-dfbd-4dbf-8a36-2ce76f72732b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2db53f8a-ce06-4031-bbf3-a21febdcece3","type":"Circle"},"selection_glyph":null,"view":{"id":"95175f31-5e30-4acd-8403-d505c8329de2","type":"CDSView"}},"id":"acbf98a3-a46d-466f-948b-3e9ca8b77c62","type":"GlyphRenderer"},{"attributes":{"source":{"id":"055c7edc-35c9-4ea3-868f-5bc222a8107d","type":"ColumnDataSource"}},"id":"e08c8f8d-5e31-4b0f-aaf3-98dc47b3d423","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[584]},"y":{"__ndarray__":"...","dtype":"float32","shape":[584]}}},"id":"58693f77-8b48-4211-93d1-ab43b132e1be","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_c ...

# %%
train_df, val_df, both_df = load_latent(name="complex2")
p = figure(plot_width=800, plot_height=700)
p.circle(train_df["latent0"], train_df["latent1"], 
         size=3, color="green", alpha=0.6, legend="train")
p.circle(val_df["latent0"], val_df["latent1"], 
         size=3, color="red", alpha=0.6, legend="val")
p.legend.click_policy="hide"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e752baa5-20a4-4b1b-9678-01bc62a758c3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("e752baa5-20a4-4b1b-9678-01bc62a758c3");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e752baa5-20a4-4b1b-9678-01bc62a758c3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e752baa5-20a4-4b1b-9678-01bc62a758c3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"63a72538-2a8e-4e3d-8689-8dbd8968d19e":{"roots":{"references":[{"attributes":{"formatter":{"id":"b93e2696-40bb-4d97-b1ea-2920647f9f45","type":"BasicTickFormatter"},"plot":{"id":"de33fa76-516f-444b-9c0e-44befbf477c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"3e1698a3-cb5c-488f-b49a-07549ff96776","type":"BasicTicker"}},"id":"ea5deb84-10a8-4779-802d-d73fb0f4a953","type":"LinearAxis"},{"attributes":{"label":{"value":"train"},"renderers":[{"id":"f8a7a344-874d-4c88-af2e-d2d91f02795b","type":"GlyphRenderer"}]},"id":"8f7e3253-ad17-48a8-a5a1-68b97662ed72","type":"LegendItem"},{"attributes":{"plot":{"id":"de33fa76-516f-444b-9c0e-44befbf477c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"439a13d9-aeab-498c-a1de-ea0436b55088","type":"BasicTicker"}},"id":"3270d226-d6a5-423c-9064-f4b8f8447f22","type":"Grid"},{"attributes":{},"id":"c6054b68-65b8-4610-918c-358fe56f12c9","type":"ResetTool"},{"attributes":{},"id":"2896bc87-a178-4a29-9994-d86bf4f975d4","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[2147]},"y":{"__ndarray__":"...","dtype":"float32","shape":[2147]}}},"id":"8ffaeefa-ae78-4de1-9dd8-25aece10d241","type":"ColumnDataSource"},{"attributes":{},"id":"3e1698a3-cb5c-488f-b49a-07549ff96776","type":"BasicTicker"},{"attributes":{},"id":"5f1d0007-f7c9-4609-80a5-d2858f1807c0","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"469863f9-c415-4894-8f99-4c39ef533392","type":"Circle"},{"attributes":{},"id":"18f19f6b-9707-44a4-9338-b38bb723c30e","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"f690d039-30a6-4946-a17e-f9237dd024a7","type":"Title"},{"attributes":{"overlay":{"id":"15beb676-c380-440b-871e-a38c6d2fc3f4","type":"BoxAnnotation"}},"id":"75e4d0d7-b9ff-4054-951b-06c4cbc7be05","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"f11b69ba-4c7f-4297-9d52-21fbf6f5eb0e","type":"ColumnDataSource"},"glyph":{"id":"9348b578-2728-4bf0-86ad-a8d1db81fc68","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3c376dcf-c684-4696-95d5-6507aa050755","type":"Circle"},"selection_glyph":null,"view":{"id":"bce8aad4-28bc-4cf5-a793-75263bcc82df","type":"CDSView"}},"id":"f8a7a344-874d-4c88-af2e-d2d91f02795b","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"15beb676-c380-440b-871e-a38c6d2fc3f4","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"18f19f6b-9707-44a4-9338-b38bb723c30e","type":"PanTool"},{"id":"74fe54e1-9ae9-4d9b-8482-c402f4b90ac0","type":"WheelZoomTool"},{"id":"75e4d0d7-b9ff-4054-951b-06c4cbc7be05","type":"BoxZoomTool"},{"id":"2896bc87-a178-4a29-9994-d86bf4f975d4","type":"SaveTool"},{"id":"c6054b68-65b8-4610-918c-358fe56f12c9","type":"ResetTool"},{"id":"5f1d0007-f7c9-4609-80a5-d2858f1807c0","type":"HelpTool"}]},"id":"0f32f423-975f-48ed-a2e4-99dee3f4ad3f","type":"Toolbar"},{"attributes":{},"id":"74fe54e1-9ae9-4d9b-8482-c402f4b90ac0","type":"WheelZoomTool"},{"attributes":{"click_policy":"hide","items":[{"id":"8f7e3253-ad17-48a8-a5a1-68b97662ed72","type":"LegendItem"},{"id":"6ca5859c-e719-49e2-b1f7-8a509d6f21f8","type":"LegendItem"}],"plot":{"id":"de33fa76-516f-444b-9c0e-44befbf477c0","subtype":"Figure","type":"Plot"}},"id":"3b32216e-9cd5-4c79-9111-e13570637eca","type":"Legend"},{"attributes":{"source":{"id":"f11b69ba-4c7f-4297-9d52-21fbf6f5eb0e","type":"ColumnDataSource"}},"id":"bce8aad4-28bc-4cf5-a793-75263bcc82df","typ ...

# %%
label_df = pd.read_csv("../data/labels.csv", index_col="sample_id")
joined_df = label_df.join(both_df)

# %%
this_df = joined_df[["label_tissue", "latent0", "latent1"]].dropna()
colored_tissues = this_df["label_tissue"].value_counts().index

p = figure(plot_width=1000, plot_height=800)
with open("../colors.txt", "r") as f:
    colors = f.read().split(",")
for i, datatype in enumerate(colored_tissues):
    subset_df = this_df[this_df["label_tissue"] == datatype]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, color=colors[i], legend=datatype)
    
p.legend.click_policy="hide"
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ee9013cb-b7a6-4f11-845f-d6d1100d026c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("ee9013cb-b7a6-4f11-845f-d6d1100d026c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee9013cb-b7a6-4f11-845f-d6d1100d026c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee9013cb-b7a6-4f11-845f-d6d1100d026c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0a785c26-7178-4763-a0e8-7633d3dcbbbf":{"roots":{"references":[{"attributes":{"label":{"value":"UCS"},"renderers":[{"id":"66dc1173-5cd2-40f0-9afb-fde2abf7adab","type":"GlyphRenderer"}]},"id":"03e1afa2-ce60-4402-b324-60d409bc3275","type":"LegendItem"},{"attributes":{"source":{"id":"b6c3fc59-3dfd-4600-b336-b44dfd0008f6","type":"ColumnDataSource"}},"id":"177a2998-5234-443b-be20-bfa2c6ec1432","type":"CDSView"},{"attributes":{"source":{"id":"59f6d87d-f6e9-4d1f-9204-26a2520e137c","type":"ColumnDataSource"}},"id":"7fcc2e7b-e7a8-49cd-a9c8-feab06207dfb","type":"CDSView"},{"attributes":{"label":{"value":"UCEC"},"renderers":[{"id":"07c580ab-8478-4154-b23d-190a48cddc24","type":"GlyphRenderer"}]},"id":"bf20c14e-13cc-4bcd-b369-6127151303b1","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"59c654f4-ad6f-4d52-b3fc-882b00caf218","type":"Circle"},{"attributes":{"data_source":{"id":"30e5ef3b-95c4-4bb2-bd9d-69ca48579c6d","type":"ColumnDataSource"},"glyph":{"id":"b3e7121a-fefe-4e02-ba04-02e7adc09f51","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"59c654f4-ad6f-4d52-b3fc-882b00caf218","type":"Circle"},"selection_glyph":null,"view":{"id":"17da3d1d-444c-4552-9c8d-276ce827f1c6","type":"CDSView"}},"id":"ae8a533c-c82e-4eec-a8d9-a0f3a1eb8a73","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#c7e9c0"},"line_color":{"value":"#c7e9c0"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"eca79700-947c-47fb-b482-21cba0fb18bf","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[527]},"y":{"__ndarray__":"...","dtype":"float32","shape":[527]}}},"id":"55abaad7-c766-440f-95a6-240c39083537","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"803b7a26-ff32-44b1-bcfc-39fc1b0c47a8","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"J4k2whxrF8KcnAPCnyoCwguwTcEfUvPBC2PLwYcMDcJjh/bB9I0+wnzZRsIor0DC0iRNwjE2QcLB4EXC58dAwiLVWsFb0lLBxwgSwuV08MFcBDvCGdMrwgDYTcKveETCDxRDwgJuU8IntmLCrkZBwvVKTMLtFkvCo9FYwQ1PUcGIeW3CU/dawbh/5cFfPc/BH3dRwX7/RcH1jlPBoFZZwRUCVcJa30nB2yslwl3YSsFw2V7CIZIRwg==","dtype":"float32","shape":[46]},"y":{"__ndarray__":"56ncwW+kvMH7sKjBEpahwaJSB8HVPJfBGRdDwb8Vq8EbcprBTQXjwU1Y8cH68OTBonn0waP76cE1ze7B2LfnwW8RD8GhnwzBH3O7waCalMHnQOPBIo7nwc+p+cF3S/bBX6vqwb25/cFSZvjBn4bqwRN888E4DPPBcZwOwXEWCMHY6gHC/SMSwVKHk8HueYfBulENwd8m7cChjgrB2bQNwR9bAMLnzwjBO4vLwWk1CsF3oAHCngCTwQ==","dtype":"float32","shape":[46]}}},"id":"30e5ef3b-95c4-4bb2-bd9d-69ca48579c6d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"55abaad7-c766-440f-95a6-240c39083537","type":"ColumnDataSource"},"glyph":{"id":"fff32ca8-9a3a-447d-95a1-a3f2ac9bc18b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"803b7a26-ff32-44b1-bcfc-39fc1b0c47a8","type":"Circle"},"selection_glyph":null,"view":{"id":"21ee0039-d631-4452-b67c-e75db7350d51","type":"CDSView"}},"id":"679b5d56-92d6-4761-95d3-ed693e8c7881","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#3f3f3f"},"line_color":{"value":"#3f3f3f"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b3e7121a-fefe-4e02-ba04-02e7adc09f51","type":"Circle"},{"attributes":{"source":{"id":"30e5ef3b-95c4-4bb2-bd9d-69ca48579c6d","type":"ColumnDataSource"}},"id":"17da3d1d-444c-4552-9c8d-276ce827f1c6","type":"CDSView"},{"attributes":{"fill_color":{"value":"#31a354"},"line_color":{"value":"#31a354"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"fff32ca8-9a3a-447d-95a1- ...

# %%
this_df = joined_df[["label_gender", "latent0", "latent1"]].dropna()
colored_genders = this_df["label_gender"].value_counts().index

p = figure(plot_width=800, plot_height=800)
colors = palettes.Category10[10]
for i, datatype in enumerate(colored_genders):
    subset_df = this_df[this_df["label_gender"] == datatype]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, 
             alpha=0.7, color=colors[i], legend=datatype)
    
p.legend.click_policy="hide"
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="430924ed-a84b-451a-b8ab-99edb4b7aa61"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("430924ed-a84b-451a-b8ab-99edb4b7aa61");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("430924ed-a84b-451a-b8ab-99edb4b7aa61");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '430924ed-a84b-451a-b8ab-99edb4b7aa61' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eb2bd321-621a-4ba4-9588-ee5c41cd19e2":{"roots":{"references":[{"attributes":{"label":{"value":"FEMALE"},"renderers":[{"id":"a44e2041-af1d-4bf0-9074-9129d263465d","type":"GlyphRenderer"}]},"id":"4541195b-6a0c-4b7e-bca3-0db733be7bab","type":"LegendItem"},{"attributes":{},"id":"d56e16a2-cde8-4aa4-9988-535fba7154b9","type":"LinearScale"},{"attributes":{"source":{"id":"8306b405-7f62-4fad-b659-cc4f65782ebf","type":"ColumnDataSource"}},"id":"6362bfad-2134-45e8-bfd1-b23916573b4f","type":"CDSView"},{"attributes":{"callback":null},"id":"e056ef45-7eb4-4565-9af9-2f8fc34173db","type":"DataRange1d"},{"attributes":{"formatter":{"id":"cddc8472-43c9-4d6e-bba4-6cba07d9c0f3","type":"BasicTickFormatter"},"plot":{"id":"2b031917-5d8e-49af-95c0-e72918f91013","subtype":"Figure","type":"Plot"},"ticker":{"id":"4817715a-b657-4f7e-9a62-156e70f153f4","type":"BasicTicker"}},"id":"5d104401-7f1d-4785-82e9-a4ad2e0935e5","type":"LinearAxis"},{"attributes":{"callback":null},"id":"67844d8b-e61d-499d-b23e-40f3d3811708","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[5301]},"y":{"__ndarray__":"...","dtype":"float32","shape":[5301]}}},"id":"77004e94-6527-4126-b53c-8fccf328cf45","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8306b405-7f62-4fad-b659-cc4f65782ebf","type":"ColumnDataSource"},"glyph":{"id":"bdf8fbbd-5124-4ed4-98ba-c135b23cb78f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dfe1730f-9736-4c09-aa4c-be81404db1a7","type":"Circle"},"selection_glyph":null,"view":{"id":"6362bfad-2134-45e8-bfd1-b23916573b4f","type":"CDSView"}},"id":"d402615c-b630-4fd1-9370-343893f56db2","type":"GlyphRenderer"},{"attributes":{},"id":"08809370-021e-4acc-81a1-1c46493fca6a","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"41fb0611-2cdf-4877-8703-c341af9b7422","type":"PanTool"},{"id":"caae017e-9cf5-4803-83ef-ff519fe386a2","type":"WheelZoomTool"},{"id":"57d89524-f267-4a2f-86ec-abf4bfb56020","type":"BoxZoomTool"},{"id":"462b9766-df1a-4351-9f27-773456cdb5b7","type":"SaveTool"},{"id":"f5b2e352-e267-492c-9e29-a2276258bf4a","type":"ResetTool"},{"id":"9052df84-3f75-4fc4-b6bf-fb5cfa230a8c","type":"HelpTool"}]},"id":"1d96a695-9595-4bb1-afbf-84759c2dc609","type":"Toolbar"},{"attributes":{"label":{"value":"MALE"},"renderers":[{"id":"d402615c-b630-4fd1-9370-343893f56db2","type":"GlyphRenderer"}]},"id":"942795b6-d208-40a1-ab2b-7226d82186d6","type":"LegendItem"},{"attributes":{"plot":{"id":"2b031917-5d8e-49af-95c0-e72918f91013","subtype":"Figure","type":"Plot"},"ticker":{"id":"36e53cac-016b-488a-9bc6-9e0ede8cb1c6","type":"BasicTicker"}},"id":"33401135-161b-4ae7-8c1f-dbcf11f28ddb","type":"Grid"},{"attributes":{},"id":"36e53cac-016b-488a-9bc6-9e0ede8cb1c6","type":"BasicTicker"},{"attributes":{"formatter":{"id":"a759bbbd-a555-4bfe-b0a6-e2f5798aadff","type":"BasicTickFormatter"},"plot":{"id":"2b031917-5d8e-49af-95c0-e72918f91013","subtype":"Figure","type":"Plot"},"ticker":{"id":"36e53cac-016b-488a-9bc6-9e0ede8cb1c6","type":"BasicTicker"}},"id":"09c1bc48-3e87-4917-bac3-c3283a30f9a7","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"af1b6053-dc36-411c-9f2a-99a4295a5e0d","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"2b031917-5d8e-49af-95c0-e72918f91013","subtype":"Figure","type":"Plot"},"ticker":{"id":"4817715a-b657-4f7e-9a62-156e70f153f4","type":"BasicTicker"}},"id":"7c26269f-6ace-467f-a2cc-3fbc28855731","type":"Grid"},{"attributes":{},"id":"4817715a-b657-4f7e-9a62-156e70f153f4","type":"BasicTicker"},{"attributes":{},"id":"a759bbbd ...

# %%
this_df = joined_df[["label_tumor", "latent0", "latent1"]].dropna()
colored_tumors = this_df["label_tumor"].value_counts().index

p = figure(plot_width=800, plot_height=800)
colors = palettes.Category10[10]
for i, datatype in enumerate(colored_tumors):
    subset_df = this_df[this_df["label_tumor"] == datatype]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, 
             alpha=0.7, color=colors[i], legend=datatype)
    
p.legend.click_policy="hide"
p.legend.location = "top_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7c28cd0b-4181-4206-b08b-04680661e40d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7c28cd0b-4181-4206-b08b-04680661e40d");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7c28cd0b-4181-4206-b08b-04680661e40d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7c28cd0b-4181-4206-b08b-04680661e40d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"65dbf39d-da69-4f88-8f96-d8770e57c53a":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#d62728"},"line_alpha":{"value":0.7},"line_color":{"value":"#d62728"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"24ea8538-90c4-49b7-abba-de6441aac41b","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3b7ff30-c9aa-40d0-afed-370368464c36","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7b38eb6e-dfa8-47cf-9cad-52ca07d36aa4","type":"Circle"},{"attributes":{"plot":{"id":"f839a801-f3ac-4b44-bb95-1394e93a9fc4","subtype":"Figure","type":"Plot"},"ticker":{"id":"136d250b-a57e-4ccb-af71-0d827dcb80ac","type":"BasicTicker"}},"id":"289fd957-306d-42c7-a30a-a10958cec301","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[697]},"y":{"__ndarray__":"...","dtype":"float32","shape":[697]}}},"id":"ca933f53-3643-4d82-b3bc-bd35e37f0447","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"555f253c-800d-4971-a2b6-6b84c15327c5","type":"ColumnDataSource"},"glyph":{"id":"24ea8538-90c4-49b7-abba-de6441aac41b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7b38eb6e-dfa8-47cf-9cad-52ca07d36aa4","type":"Circle"},"selection_glyph":null,"view":{"id":"da36966f-4f44-4a89-9f28-d206aaa4b298","type":"CDSView"}},"id":"90ad936f-bebb-44f3-b0e2-5885d9d7ac3f","type":"GlyphRenderer"},{"attributes":{"source":{"id":"555f253c-800d-4971-a2b6-6b84c15327c5","type":"ColumnDataSource"}},"id":"da36966f-4f44-4a89-9f28-d206aaa4b298","type":"CDSView"},{"attributes":{"below":[{"id":"4c67c3f2-dfd1-4a9c-af34-08d47a71272a","type":"LinearAxis"}],"left":[{"id":"13240f9f-f208-49a5-9459-5eedc3d23fd0","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"4c67c3f2-dfd1-4a9c-af34-08d47a71272a","type":"LinearAxis"},{"id":"289fd957-306d-42c7-a30a-a10958cec301","type":"Grid"},{"id":"13240f9f-f208-49a5-9459-5eedc3d23fd0","type":"LinearAxis"},{"id":"b0e31268-1b0e-43f1-86d1-c51306b5249b","type":"Grid"},{"id":"30034982-d550-4d15-8565-0cdacbc78a4d","type":"BoxAnnotation"},{"id":"c06fe339-902f-412b-87ba-0e722609c3f4","type":"Legend"},{"id":"b79a5db5-acdd-47b6-abb3-e35dcba93366","type":"GlyphRenderer"},{"id":"505b9855-57a9-4f3e-8e4d-ddf6fd987605","type":"GlyphRenderer"},{"id":"0a3c502f-cb31-4829-b483-2fd98e0e7b18","type":"GlyphRenderer"},{"id":"90ad936f-bebb-44f3-b0e2-5885d9d7ac3f","type":"GlyphRenderer"},{"id":"6bab4a80-3db5-4964-9234-cebcf637dffd","type":"GlyphRenderer"}],"title":{"id":"7209aafb-a79c-4e86-8df0-c6270cd57b21","type":"Title"},"toolbar":{"id":"ba68b34c-467c-45fd-924e-bf2e4480d45c","type":"Toolbar"},"x_range":{"id":"9ce55176-1fe6-4b81-bca6-4343f1faf86b","type":"DataRange1d"},"x_scale":{"id":"a90306ea-caab-4b52-85e5-b7fc0a411c7f","type":"LinearScale"},"y_range":{"id":"fb6ef235-65aa-4896-a372-07cf5e9ddf4e","type":"DataRange1d"},"y_scale":{"id":"5ba2ab40-474c-4ef4-8195-24089755300b","type":"LinearScale"}},"id":"f839a801-f3ac-4b44-bb95-1394e93a9fc4","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"d9f49122-2fea-4dce-9746-2cb1d0053ae4","type":"BasicTickFormatter"},"plot":{"id":"f839a801-f3ac-4b44-bb95-1394e93a9fc4","subtype":"Figure","type":"Plot"},"ticker":{"id":"136d250b-a57e-4ccb-af71-0d827dcb80ac","type":"BasicTicker"}},"id":"4c67c3f2-dfd1-4a9c-af34-08d47a71272a","type":"LinearAxis"},{"attributes":{"overlay":{"id":"30034982-d550-4d15-8565-0cdacbc78a4d","type":"BoxAnnotation"}},"id":"6a3efb4c-7e5b-4914-9c3b-fa0f8f25a00f","type":"BoxZoomTool"},{"attributes":{"source":{"id":"40897 ...

# %%
this_df = joined_df[["label_age", "latent0", "latent1"]].dropna()
this_df["age_bin"] = this_df["label_age"].apply(lambda x:int(x/10)-1)

p = figure(plot_width=800, plot_height=800)
colors = palettes.Category10[10]
rainbow = palettes.RdBu11[:4] + palettes.RdBu11[-5:]
for i in sorted(list(set(this_df["age_bin"]))):
    subset_df = this_df[this_df["age_bin"] == i]
    p.circle(subset_df["latent0"], subset_df["latent1"], size=3, 
             alpha=0.7, color=rainbow[i], legend="{0}0s".format(i+1))
    
p.legend.click_policy="hide"
p.legend.location = "top_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6fc59148-254c-4510-b407-0a8e8a11e5fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6fc59148-254c-4510-b407-0a8e8a11e5fe");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6fc59148-254c-4510-b407-0a8e8a11e5fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6fc59148-254c-4510-b407-0a8e8a11e5fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3a1a081a-7aeb-4848-9475-4e8d78228564":{"roots":{"references":[{"attributes":{"data_source":{"id":"83cf6148-9b1c-444c-b09b-543e218678d7","type":"ColumnDataSource"},"glyph":{"id":"da5dd59c-53b0-45f9-8abe-85376e237456","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8a2607be-fc65-4d18-bd31-d47dba0164b1","type":"Circle"},"selection_glyph":null,"view":{"id":"0db0efc7-3adb-4e92-9079-94ffcf673915","type":"CDSView"}},"id":"6e4a2887-d5c6-4a33-92f8-9a14bced9d13","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"6d93b3b6-a1b1-453e-a968-44b536cf0d58","type":"Title"},{"attributes":{"data_source":{"id":"c3bc13a4-86cd-402b-83f7-acdc0b693b9f","type":"ColumnDataSource"},"glyph":{"id":"74a77e64-d277-4fbb-9ac3-79dc048d000e","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"70a2596d-409e-4a4e-bdd3-97389b403860","type":"Circle"},"selection_glyph":null,"view":{"id":"c493014c-90ed-47b9-8210-b3354d9fe24a","type":"CDSView"}},"id":"d43b7fac-db08-412e-88d0-6117801171e0","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"c570bc60-f5f6-45ec-9d6a-e71f24ba883f","type":"LinearAxis"}],"left":[{"id":"381571ac-1d94-4d71-916d-af7bc5842be2","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"c570bc60-f5f6-45ec-9d6a-e71f24ba883f","type":"LinearAxis"},{"id":"92200098-fb42-4aef-a9d3-185ac3e8ed8f","type":"Grid"},{"id":"381571ac-1d94-4d71-916d-af7bc5842be2","type":"LinearAxis"},{"id":"3e5a35d0-b4a1-405c-aad0-c94cf1926a02","type":"Grid"},{"id":"1a66504f-dfc7-4b21-b548-c2ba97332c89","type":"BoxAnnotation"},{"id":"ae78b850-a472-49c4-94d7-b5fdf96612c4","type":"Legend"},{"id":"1c9db3d4-52e5-4cc7-9c21-35ef5aecce63","type":"GlyphRenderer"},{"id":"d43b7fac-db08-412e-88d0-6117801171e0","type":"GlyphRenderer"},{"id":"ea5b01e6-6125-492b-b7c1-36a6c7255ee5","type":"GlyphRenderer"},{"id":"6e4a2887-d5c6-4a33-92f8-9a14bced9d13","type":"GlyphRenderer"},{"id":"86da73e0-e835-49a1-8908-9be08761184c","type":"GlyphRenderer"},{"id":"734e101a-430a-488f-85a9-5eca2a79f39b","type":"GlyphRenderer"},{"id":"3581fa12-c0cc-4a32-a562-fa389593b3a3","type":"GlyphRenderer"},{"id":"a2e2cce1-bbd8-4e86-9027-ecf937d49c4b","type":"GlyphRenderer"},{"id":"a5569df7-172b-4d39-83c1-b0325a78e9f0","type":"GlyphRenderer"}],"title":{"id":"6d93b3b6-a1b1-453e-a968-44b536cf0d58","type":"Title"},"toolbar":{"id":"6c2e94ec-cfc9-4969-be97-4d8e66c01086","type":"Toolbar"},"x_range":{"id":"e11caf8d-e261-4778-8a1b-313ed54ae7b9","type":"DataRange1d"},"x_scale":{"id":"9c03d7bd-edbe-4ed0-a666-61cc093e180b","type":"LinearScale"},"y_range":{"id":"ae2a0337-b331-4121-9cbd-e89421a0318d","type":"DataRange1d"},"y_scale":{"id":"ba4dd108-fc7d-470b-99c3-d51de7208dc6","type":"LinearScale"}},"id":"bc30fe74-ffd7-4bd3-8664-636636cb2ce9","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#92c5de"},"line_alpha":{"value":0.7},"line_color":{"value":"#92c5de"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"da5dd59c-53b0-45f9-8abe-85376e237456","type":"Circle"},{"attributes":{"data_source":{"id":"bcccfba8-3b3a-4b54-a674-5adf03455e72","type":"ColumnDataSource"},"glyph":{"id":"cd1ed25a-cf7a-4141-9427-fdf9001a26a3","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7c7dc563-414d-4da4-849c-68659c591fca","type":"Circle"},"selection_glyph":null,"view":{"id":"ef69f9d2-e9ac-40a5-aa32-e663f8ff8dda","type":"CDSView"}},"id":"734e101a-430a-488f-85a9-5eca2a79f39b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[1372]},"y":{"__ndarray__":"...","dtype":"float32","shape":[1372]}}},"id":"83cf6148-9b1c-444c-b09b-543e218678d7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"seEmws8PPcJVT0rCzmwXwrb9v8EyFJLB5iHHwXKu08H1wM7Bs23CwfjoasLLJ1TBgQOtwAnfI8IETwDBH74HwZM5JsKb ...
