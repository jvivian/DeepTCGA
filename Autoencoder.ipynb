# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import time
import datetime
from pprint import pprint as pp

import load_data

# %%
def fc_layer(A_prev, size_in, size_out, name="fully-connected"):
    with tf.name_scope(name):
        w = tf.Variable(tf.truncated_normal([size_in, size_out], mean=0, stddev=0.1))
        b = tf.Variable(tf.constant(0.1, shape=[size_out]))
        act = tf.matmul(A_prev, w) + b
        tf.summary.histogram("weights", w)
        tf.summary.histogram("biases", b)
        tf.summary.histogram("activations", act)
        return act, w, b

    
def build_model(x, N_IN, N_HIDDEN):
    parameters = {}
    z1, w1, b1 = fc_layer(x, N_IN, N_HIDDEN, name="fc1")
    parameters.update({"z1":z1, "w1": w1, "b1": b1})
    hidden = tf.nn.leaky_relu(z1, name="hidden")
    x_recon, w2, b2 = fc_layer(hidden, N_HIDDEN, N_IN, name="fc2")
    parameters.update({"w2": w2, "b2": b2})
    return x_recon, parameters


def build_model1(x, N_IN, N_HIDDENS):
    parameters = {}
    
    a1, w1, b1 = fc_layer(x, N_IN, N_HIDDENS[0], name="fc1")
    parameters.update({"a1":a1, "w1": w1, "b1": b1})
    hidden1 = tf.nn.relu(a1, name="hidden1")
    
    a2, w2, b2 = fc_layer(hidden1, N_HIDDENS[0], N_HIDDENS[1], name="fc2")
    parameters.update({"a2":a2, "w2": w2, "b2": b2})
    hidden2 = tf.nn.relu(a2, name="hidden2")
    
    a3, w3, b3 = fc_layer(hidden2, N_HIDDENS[1], N_HIDDENS[2], name="fc3")
    parameters.update({"a3":a3, "w3": w3, "b3": b3})
    hidden3 = tf.nn.relu(a3, name="hidden3")
    
    x_recon, w4, b4 = fc_layer(hidden3, N_HIDDENS[2], N_IN, name="fc4")
    parameters.update({"w4": w4, "b4": b4})
    return x_recon, parameters


def back_prop(x, x_recon, learning_rate):
    loss = tf.reduce_mean(tf.square(x_recon - x))
    train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)
    return train_step


def feed_forward(x, parameters):
    w1, b1 = parameters["w1"], parameters["b1"]
    hidden = tf.nn.leaky_relu(tf.matmul(x, w1) + b1)
    w2, b2 = parameters["w2"], parameters["b2"]
    x_recon = tf.matmul(hidden, w2) + b2
    return x_recon, hidden


def feed_forward1(x, parameters):
    w1, b1 = parameters["w1"], parameters["b1"]
    hidden1 = tf.nn.relu(tf.matmul(x, w1) + b1)
    w2, b2 = parameters["w2"], parameters["b2"]
    hidden2 = tf.nn.relu(tf.matmul(hidden1, w2) + b2)
    w3, b3 = parameters["w3"], parameters["b3"]
    hidden3 = tf.nn.relu(tf.matmul(hidden2, w3) + b3)
    w4, b4 = parameters["w4"], parameters["b4"]
    x_recon = tf.matmul(hidden3, w4) + b4
    return x_recon, hidden2


def mse(x, x_recon, name=""):
    mse = tf.reduce_mean(tf.square(x_recon-x))
    mse_summary = tf.summary.scalar(name + "_mse", mse)
    return mse, mse_summary

# %%
def train_model(data, batch_size=128, num_epoch=1000, learning_rate=1e-3, extra=""):
    tf.reset_default_graph()
    LOGDIR = "/tmp/tcga_{0}".format(datetime.datetime.today().date())
    N_IN = data.train.num_features
    N_OUT = data.train.num_features
    N_HIDDEN = 2
    
    # train step
    (train_batch, train_iter, val_all, val_iter, 
        train_all, train_iter_all) = data.prep_batch(batch_size=batch_size, 
                                                     count_by="epoch")
    x = train_batch["X"]
    x_recon, parameters = build_model(x, N_IN, N_HIDDEN)
    train_step = back_prop(x, x_recon, learning_rate)
    
    # mse
    x_train, x_val = train_all["X"], val_all["X"]
    x_train_recon, _ = feed_forward(x_train, parameters)
    x_val_recon, _ = feed_forward(x_val, parameters)
    train_mse, train_summ = mse(x_train, x_train_recon, name="train")
    val_mse, val_summ = mse(x_val, x_val_recon, name="valiation")
    
    # run
    sess = tf.Session()
    summ = tf.summary.merge_all()
    writer = tf.summary.FileWriter(LOGDIR + "ae_{0}".format(extra))
    writer.add_graph(sess.graph)                            
    sess.run(tf.global_variables_initializer())

    for epoch in range(num_epoch):
        sess.run([train_iter.initializer])
        t0 = time.time()
        try:
            while True:
                sess.run(train_step)
#             parameters_test = sess.run(parameters)
#             print("summation of w1")
#             print(np.sum(parameters_test["w1"]))
#             print("summation of w2")
#             print(np.sum(parameters_test["w2"]))
#             for i in range(10):
#                 sess.run(train_step)
#             parameters_test = sess.run(parameters)
#             print("summation of w1")
#             print(np.sum(parameters_test["w1"]))
#             print("summation of w2")
#             print(np.sum(parameters_test["w2"]))
            
#             x_test = sess.run(x)
#             print("x")
#             print(x_test)
#             print("manually multiply to get hidden")
#             print(np.dot(x_test, parameters_test["w1"])+parameters_test["b1"])
        except tf.errors.OutOfRangeError:
            sess.run([train_iter_all.initializer, val_iter.initializer])
            [train_error, train_s, val_error, val_s] = sess.run(
                [train_mse, train_summ, val_mse, val_summ])
            writer.add_summary(train_s, epoch)
            writer.add_summary(val_s, epoch)
            if epoch % 10 == 0:
                print("epoch", epoch)
                print("training mse:", train_error, "validation mse", val_error)
                print("epoch time:", time.time()-t0)                             
    sess.close()

# %%
tcga = load_data.read_data_sets("./data/mRNA_lognorm_StandardScaled.hdf")

# %%
train_model(tcga, num_epoch=1000, extra="leaky_relu")
# Out:
# epoch 0
# training mse: 1.046216 validation mse 1.0447824
# epoch time: 2.357882022857666
# epoch 10
# training mse: 0.7953922 validation mse 0.7928093
# epoch time: 0.9783875942230225
# epoch 20
# training mse: 0.7895339 validation mse 0.78746295
# epoch time: 0.9680678844451904
# epoch 30
# training mse: 0.78661895 validation mse 0.7855131
# epoch time: 0.9656424522399902
# epoch 40
# training mse: 0.7848398 validation mse 0.78509253
# epoch time: 0.9638805389404297
# epoch 50
# training mse: 0.78361934 validation mse 0.78512067
# epoch time: 0.9611928462982178
# epoch 60
# training mse: 0.78279203 validation mse 0.7862348
# epoch time: 0.9613471031188965
# epoch 70
# training mse: 0.7816517 validation mse 0.7868597
# epoch time: 0.9662091732025146
# epoch 80
# training mse: 0.7809495 validation mse 0.7882334
# epoch time: 0.977529764175415
# epoch 90
# training mse: 0.78028595 validation mse 0.7893807
# epoch time: 0.9817895889282227
# epoch 100
# training mse: 0.78039134 validation mse 0.791649
# epoch time: 0.9655599594116211
# epoch 110
# training mse: 0.7799816 validation mse 0.7926289
# epoch time: 0.9612100124359131
# epoch 120
# training mse: 0.77944165 validation mse 0.79340154
# epoch time: 0.9731457233428955
# epoch 130
# training mse: 0.7792977 validation mse 0.7944737
# epoch time: 0.9610273838043213
# epoch 140
# training mse: 0.7796682 validation mse 0.7964419
# epoch time: 0.955582857131958
# epoch 150
# training mse: 0.77923274 validation mse 0.7968599
# epoch time: 0.9460129737854004
# epoch 160
# training mse: 0.7792536 validation mse 0.79844785
# epoch time: 0.9806981086730957
# epoch 170
# training mse: 0.77904403 validation mse 0.7986735
# epoch time: 0.9723069667816162
# epoch 180
# training mse: 0.779288 validation mse 0.79942936
# epoch time: 0.9837512969970703
# epoch 190
# training mse: 0.77973235 validation mse 0.8005258
# epoch time: 0.9568605422973633
# epoch 200
# training mse: 0.7794423 validation mse 0.8013633
# epoch time: 0.9650804996490479
# epoch 210
# training mse: 0.7790449 validation mse 0.8003743
# epoch time: 0.9733068943023682
# epoch 220
# training mse: 0.77871096 validation mse 0.8000102
# epoch time: 0.963097333908081
# epoch 230
# training mse: 0.779135 validation mse 0.8009992
# epoch time: 0.9687695503234863
# epoch 240
# training mse: 0.77876145 validation mse 0.8015409
# epoch time: 0.9772541522979736
# epoch 250
# training mse: 0.77881384 validation mse 0.80197746
# epoch time: 0.9699125289916992
# epoch 260
# training mse: 0.77840644 validation mse 0.8021544
# epoch time: 0.9768846035003662
# epoch 270
# training mse: 0.77899456 validation mse 0.8028335
# epoch time: 0.9638206958770752
# epoch 280
# training mse: 0.7788438 validation mse 0.802167
# epoch time: 0.9594109058380127
# epoch 290
# training mse: 0.7791979 validation mse 0.8026385
# epoch time: 0.9738340377807617
# epoch 300
# training mse: 0.7790132 validation mse 0.8036728
# epoch time: 0.9718308448791504
# epoch 310
# training mse: 0.7786181 validation mse 0.80284005
# epoch time: 0.9738473892211914
# epoch 320
# training mse: 0.77855194 validation mse 0.80348027
# epoch time: 0.989525556564331
# epoch 330
# training mse: 0.7786822 validation mse 0.8030269
# epoch time: 0.9740312099456787
# epoch 340
# training mse: 0.779037 validation mse 0.8030772
# epoch time: 0.9865479469299316
# epoch 350
# training mse: 0.7786663 validation mse 0.8029784
# epoch time: 0.9743754863739014
# epoch 360
# training mse: 0.77873266 validation mse 0.80293
# epoch time: 0.9803335666656494
# epoch 370
# training mse: 0.779284 validation mse 0.8040349
# epoch time: 0.9881668090820312
# epoch 380
# training mse: 0.7784744 validation mse 0.8035758
# epoch time: 0.9651131629943848
# epoch 390
# training mse: 0.77844775 validation mse 0.80403334
# epoch time: 0.972083330154419
# epoch 400
# training mse: 0.7790468 validation mse 0.8031715
# epoch time: 0.9697356224060059
# epoch 410
# training mse: 0.7782996 validation mse 0.80398285
# epoch time: 0.9709200859069824
# epoch 420
# training mse: 0.7793809 validation mse 0.804994
# epoch time: 0.9765839576721191
# epoch 430
# training mse: 0.77840465 validation mse 0.8046454
# epoch time: 0.9619922637939453
# epoch 440
# training mse: 0.7784887 validation mse 0.80473286
# epoch time: 0.9918334484100342
# epoch 450
# training mse: 0.7786024 validation mse 0.80354
# epoch time: 0.9785504341125488
# epoch 460
# training mse: 0.77852106 validation mse 0.8047744
# epoch time: 0.9650163650512695
# epoch 470
# training mse: 0.77893883 validation mse 0.80476785
# epoch time: 0.9747624397277832
# epoch 480
# training mse: 0.7794697 validation mse 0.80566186
# epoch time: 0.9706153869628906
# epoch 490
# training mse: 0.7786285 validation mse 0.8048543
# epoch time: 0.9751856327056885
# epoch 500
# training mse: 0.7788913 validation mse 0.8064158
# epoch time: 0.9718496799468994
# epoch 510
# training mse: 0.77858526 validation mse 0.80541
# epoch time: 0.9725539684295654
# epoch 520
# training mse: 0.77906764 validation mse 0.8045125
# epoch time: 0.9542524814605713
# epoch 530
# training mse: 0.77875483 validation mse 0.8048028
# epoch time: 0.9895341396331787
# epoch 540
# training mse: 0.7784644 validation mse 0.8056174
# epoch time: 0.967571496963501
# epoch 550
# training mse: 0.7786206 validation mse 0.8046226
# epoch time: 0.9591155052185059
# epoch 560
# training mse: 0.7784823 validation mse 0.8053521
# epoch time: 0.9731330871582031
# epoch 570
# training mse: 0.7785919 validation mse 0.805272
# epoch time: 0.9711720943450928
# epoch 580
# training mse: 0.7786186 validation mse 0.80605215
# epoch time: 0.9690582752227783
# epoch 590
# training mse: 0.7786903 validation mse 0.80544096
# epoch time: 0.9724411964416504
# epoch 600
# training mse: 0.77878594 validation mse 0.8064636
# epoch time: 0.9737434387207031
# epoch 610
# training mse: 0.77834225 validation mse 0.8051964
# epoch time: 0.9702234268188477
# epoch 620
# training mse: 0.77869457 validation mse 0.8053099
# epoch time: 0.983130931854248
# epoch 630
# training mse: 0.7788406 validation mse 0.80570066
# epoch time: 0.978477954864502
# epoch 640
# training mse: 0.7784673 validation mse 0.80562043
# epoch time: 0.9734878540039062
# epoch 650
# training mse: 0.7784047 validation mse 0.80540746
# epoch time: 0.977409839630127
# epoch 660
# training mse: 0.7784986 validation mse 0.8059927
# epoch time: 0.9586343765258789
# epoch 670
# training mse: 0.7782208 validation mse 0.80512726
# epoch time: 0.9783613681793213
# epoch 680
# training mse: 0.7783728 validation mse 0.8061667
# epoch time: 0.9620676040649414
# epoch 690
# training mse: 0.77901167 validation mse 0.8067266
# epoch time: 0.96380615234375
# epoch 700
# training mse: 0.7792332 validation mse 0.8068161
# epoch time: 0.9716310501098633
# epoch 710
# training mse: 0.77838 validation mse 0.8065341
# epoch time: 0.9864163398742676
# epoch 720
# training mse: 0.77849215 validation mse 0.80537534
# epoch time: 0.9695394039154053
# epoch 730
# training mse: 0.7785522 validation mse 0.8067941
# epoch time: 0.9590127468109131
# epoch 740
# training mse: 0.77823675 validation mse 0.8056039
# epoch time: 0.9561271667480469
# epoch 750
# training mse: 0.779094 validation mse 0.8065033
# epoch time: 0.9852802753448486
# epoch 760
# training mse: 0.77848846 validation mse 0.806094
# epoch time: 0.9594681262969971
# epoch 770
# training mse: 0.77841127 validation mse 0.8062902
# epoch time: 0.9840867519378662
# epoch 780
# training mse: 0.7785097 validation mse 0.8059572
# epoch time: 0.9658939838409424
# epoch 790
# training mse: 0.77923334 validation mse 0.8057352
# epoch time: 0.9777610301971436
# epoch 800
# training mse: 0.7788746 validation mse 0.80676657
# epoch time: 0.9592304229736328
# epoch 810
# training mse: 0.7786801 validation mse 0.80546147
# epoch time: 0.9745290279388428
# epoch 820
# training mse: 0.77895254 validation mse 0.8050346
# epoch time: 0.968390703201294
# epoch 830
# training mse: 0.7783957 validation mse 0.8071959
# epoch time: 0.9561624526977539
# epoch 840
# training mse: 0.7784182 validation mse 0.8049192
# epoch time: 0.9738514423370361
# epoch 850
# training mse: 0.7782971 validation mse 0.80627584
# epoch time: 0.9601292610168457
# epoch 860
# training mse: 0.7785768 validation mse 0.80649066
# epoch time: 0.9859459400177002
# epoch 870
# training mse: 0.7784806 validation mse 0.8065719
# epoch time: 0.9657480716705322
# epoch 880
# training mse: 0.7793487 validation mse 0.8084388
# epoch time: 0.9803290367126465
# epoch 890
# training mse: 0.7791689 validation mse 0.807249
# epoch time: 0.9579062461853027
# epoch 900
# training mse: 0.7783557 validation mse 0.8059696
# epoch time: 0.969404935836792
# epoch 910
# training mse: 0.7795923 validation mse 0.8079551
# epoch time: 0.9787192344665527
# epoch 920
# training mse: 0.78025854 validation mse 0.8082671
# epoch time: 0.9740948677062988
# epoch 930
# training mse: 0.77872485 validation mse 0.80653024
# epoch time: 0.9857721328735352
# epoch 940
# training mse: 0.7785599 validation mse 0.8067357
# epoch time: 0.9744472503662109
# epoch 950
# training mse: 0.7788307 validation mse 0.8064212
# epoch time: 0.9661152362823486
# epoch 960
# training mse: 0.7781791 validation mse 0.8068779
# epoch time: 0.9586648941040039
# epoch 970
# training mse: 0.77881324 validation mse 0.80662173
# epoch time: 0.9708707332611084
# epoch 980
# training mse: 0.77861804 validation mse 0.80546457
# epoch time: 0.9746019840240479
# epoch 990
# training mse: 0.7787448 validation mse 0.8067895
# epoch time: 0.9653594493865967

# %%
def train_model1(data, batch_size=128, num_epoch=1000, learning_rate=1e-3, extra=""):
    tf.reset_default_graph()
    LOGDIR = "/tmp/tcga_{0}".format(datetime.datetime.today().date())
    N_IN = data.train.num_features
    N_OUT = data.train.num_features
    N_HIDDENS = [1000, 1, 1000]
    
    # train step
    (train_batch, train_iter, val_all, val_iter, 
        train_all, train_iter_all) = data.prep_train_batch(batch_size=batch_size, fold=1)
    x = train_batch["X"]
    x_recon, parameters = build_model1(x, N_IN, N_HIDDENS)
    train_step = back_prop(x, x_recon, learning_rate)
    
    # mse
    x_train, x_val = train_all["X"], val_all["X"]
    x_train_recon1, hidden2 = feed_forward1(x_train, parameters)
    x_val_recon1, _ = feed_forward1(x_val, parameters)
    train_mse, train_summ = mse(x_train, x_train_recon1, name="train")
    val_mse, val_summ = mse(x_val, x_val_recon1, name="valiation")
    
    # run
    sess = tf.Session()
    summ = tf.summary.merge_all()
    writer = tf.summary.FileWriter(LOGDIR + "ae_{0}".format(extra))
    writer.add_graph(sess.graph)                            
    sess.run(tf.global_variables_initializer())

    for epoch in range(num_epoch):
        sess.run([train_iter.initializer])
        t0 = time.time()
        try:
            while True:
                sess.run(train_step)
        except tf.errors.OutOfRangeError:
            sess.run([train_iter_all.initializer, val_iter.initializer])
            [train_error, train_s, val_error, val_s] = sess.run(
                [train_mse, train_summ, val_mse, val_summ])
            writer.add_summary(train_s, epoch)
            writer.add_summary(val_s, epoch)
            print("epoch", epoch)
            print("training mse:", train_error, "validation mse", val_error)
            print("epoch time:", time.time()-t0)                             
    sess.close()

# %%
train_model1(tcga, num_epoch=1, extra="10_hidden")
# Out:
# epoch 0
# training mse: 0.015309443 validation mse 0.015218355
# epoch time: 3.01918888092041
